# %%
numbers = [10,20,30,40,50,100] #int
float_numbers = [10.20, 20.25, 12.32, 11.50] #float
fruits = ['Apple', 'Orange', 'Mango'] #string
Mix = [10, 20.25, 'Apple', True] #All types

# %%
#Access
print("First number: ", numbers[0])
print("Second number: " ,numbers[3])

#update number
numbers[0] = 100
print("Update number:", numbers[0])

#Slice
new_list = numbers[0:3]
print("New List: ", new_list)

#Add iteam
numbers.append(80)
print(numbers)

#insert any position
numbers.insert(1, 45)
print(numbers)

#Pop from last
numbers.pop()
print(numbers)

#remove numbers
numbers.remove(100)
print(numbers)

3
# Out:
# First number:  10
# Second number:  40
# Update number: 100
# New List:  [100, 20, 30]
# [100, 20, 30, 40, 50, 100, 80]
# [100, 45, 20, 30, 40, 50, 100, 80]
# [100, 45, 20, 30, 40, 50, 100]
# [45, 20, 30, 40, 50, 100]
# 3

# %%
list_er_modde_list = [[10,20,30], [40,50,60], [70,80,90]]
print(list_er_modde_list)
print(list_er_modde_list[0])
print(list_er_modde_list[0][1])
# Out:
# [[10, 20, 30], [40, 50, 60], [70, 80, 90]]
# [10, 20, 30]
# 20
