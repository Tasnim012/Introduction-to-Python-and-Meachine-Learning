# %%
prompt = "What is your name?"

print(prompt, type(prompt))
# Out:
# What is your name? <class 'str'>

# %%
message = """Tell me about your self? what are the issues you've been facing while learning to code?
How are you tackling them?
"""
print(message)
# Out:
# Tell me about your self? what are the issues you've been facing while learning to code?
# How are you tackling them?

# %%
str = "Hello World"
first_word = str[0]
second_word = str[1]
six_word = str[5]
print(first_word)
print(second_word)
print(six_word)
# Out:
# H
# e

# %%
first_message = message[0:25:1]
print(first_message)
# Out:
# Tell me about your self?

# %%
print(first_message[-1])
print(first_message[-2])
print(first_message[-3])
# Out:
#
# ?
# f

# %%
new_first_message = first_message[::-1]
print(new_first_message)
# Out:
#  ?fles ruoy tuoba em lleT
