# %%
prompt = "What is Phitron ?"
tokens = prompt.split()

print(tokens)
# Out:
# ['What', 'is', 'Phitron', '?']

# %%
prompt = "What_is_Phitron_?"
tokens = prompt.split("_")

print(tokens)
# Out:
# ['What', 'is', 'Phitron', '?']

# %%
join = " ".join(tokens)
print(join)
# Out:
# What is Phitron ?

# %%
join = "_".join(tokens)
print(join)
# Out:
# What_is_Phitron_?

# %%
print(type(tokens))
print(type(join))
# Out:
# <class 'list'>
# <class 'str'>

# %%
name = "Adil"
age = 23
height = 6.2

print(f"His name is {name}.\nHe is {age} years old.\nHe is {height} feet tall.")
# Out:
# His name is Adil.
# He is 23 years old.
# He is 6.2 feet tall.

# %%
name = "Adil"
age = 23
height = 6.22225

info = f"His name is {name.upper()}.\nHe is {age} years old.\nHe is {height : .3} feet tall."
print(info)
# Out:
# His name is ADIL.
# He is 23 years old.
# He is  6.22 feet tall.

# %%
model_accuracy = 0.8333

print(f"Model accuracy is {model_accuracy}")
# Out:
# Model accuracy is 0.8333

# %%
model_accuracy = 0.8333

print(f"Model accuracy is {model_accuracy :.3%}")
# Out:
# Model accuracy is 83.330%

# %%
model_accuracy = 0.8333

print(f"Model accuracy is {model_accuracy + 10}")
# Out:
# Model accuracy is 10.8333
