# %%
phone_number = 1234567891
print(phone_number)
# Out:
# 1234567891

# %%
name = "Shawon"
print(name)
# Out:
# Shawon

# %%
x = 10
y = 10.5
name = "Tasnim"
is_passed = True

# %%
print(type(x))
print(type(y))
print(type(name))
print(type(is_passed))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
