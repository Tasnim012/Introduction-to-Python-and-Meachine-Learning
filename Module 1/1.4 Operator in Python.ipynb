# %%
x = 10
y = 20

sum = x + y
sub = x - y
mul = x * y
div = x / y
mod = x % y

# %%
print(sum, sub, mul, div, mod)
# Out:
# 30 -10 200 0.5 10

# %%
x = 10
y = 20

greater_than = x > y
greater_than_equal = x >= y
less_than = x < y
less_than_equal = x <= y
equal = x == y
equal_or_not = x != y

# %%
print(greater_than)
print(greater_than_equal)
print(less_than)
print(less_than_equal)
print(equal)
print(equal_or_not)
# Out:
# False
# False
# True
# True
# False
# True
