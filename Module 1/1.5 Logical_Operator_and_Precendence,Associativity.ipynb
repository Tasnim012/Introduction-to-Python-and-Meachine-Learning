# %%
x = 10 
y = 5
z = 4

result = (x > y) and (x > z)
print(result) #and operator e duita condition true holei then output true asbe
# Out:
# True

# %%
x = 10 
y = 5
z = 50

result = (x > y) and (x > z)
print(result) #and operator e je kono ekta condition jodi false hoi tahole output false asbe
# Out:
# False

# %%
x = 10 
y = 5
z = 50

result = (x > y) or (x > z)
print(result) #je kono ekta true hole output true asbe
# Out:
# True

# %%
x = 10 
y = 20
z = 50

result = (x > y) or (x > z)
print(result)
# Out:
# False

# %% [markdown]
# ## Precedence and Associativity

# %%
# Calculate korbo left to right
# Multiplicative [*, /, %]
# Additive [+, -]
# Relational [<, <=, >, =>]
# Equality [==, !=]

eq = 10 + 10 / 2 - 5 * 2
eq
# Out:
# 5.0

# %%
eq = (10 + 10) / 2 - 5 * 2 # [] () . -> egulo thakle age egular kaj hobe
eq
# Out:
# 0.0
