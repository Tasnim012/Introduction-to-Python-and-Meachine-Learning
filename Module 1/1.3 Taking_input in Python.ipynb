# %%
name = input("What is your name? ")
print(name)
# Out:
# Shawon

# %%
age = input("What is your age? ")
print(age)
print(type(age))
# Out:
# 22
# <class 'str'>

# %%
#height = int(input("What is your height? ")) evabeo neya jai input
age = input("What is your age? ") #String hisebe input nei
age = int(age) #string ke int e convert 
print(age)
print(type(age))
# Out:
# 25
# <class 'int'>

# %%
#height = float(input("What is your height? ")) evabeo neya jai input
height = input("What is your height? ") #String hisebe input nei
height = float(height) #string ke float e convert 
print(height)
print(type(height))
# Out:
# 20.5
# <class 'float'>
