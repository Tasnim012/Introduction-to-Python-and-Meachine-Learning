# %%
count = 1

while count < 10:
    print("Hello World")
    count += 1
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World

# %%
count = 1

while count < 10:
    print("Count ", count)
    count += 1
# Out:
# Count  1
# Count  2
# Count  3
# Count  4
# Count  5
# Count  6
# Count  7
# Count  8
# Count  9

# %%
count = 10

while count < 10:
    print("Hello World!")
    count = count + 1
print(count)
# Out:
# 10
