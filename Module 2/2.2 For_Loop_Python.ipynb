# %%
for i in range(10):
    print("Hello World")
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World

# %%
for i in range(1, 11, 1): #range(start, end, step)
    print(i,": Hello World")
# Out:
# 1 : Hello World
# 2 : Hello World
# 3 : Hello World
# 4 : Hello World
# 5 : Hello World
# 6 : Hello World
# 7 : Hello World
# 8 : Hello World
# 9 : Hello World
# 10 : Hello World

# %%
for i in range(1,5):
    for j in range(1,3):
        print(i, j)
# Out:
# 1 1
# 1 2
# 2 1
# 2 2
# 3 1
# 3 2
# 4 1
# 4 2
