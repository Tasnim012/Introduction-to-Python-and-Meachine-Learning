# %%
raining = True

if raining == True:
    print("Rain coat is Necesssary")
else:
    print("Go without a rain coat")
# Out:
# Rain coat is Necesssary

# %%
raining = False

if raining == True:
    print("Rain coat is Necesssary")
else:
    print("Go without a rain coat")
# Out:
# Go without a rain coat

# %%
raining = True
Muddy = True

if raining == True:
    print("Rain coat is Necesssary")
    if Muddy == True:
        print("Wear sandal")
else:
    print("Go without a rain coat")
# Out:
# Rain coat is Necesssary
# Wear sandal

# %%
raining = True
Muddy = False

if raining == True:
    print("Rain coat is Necesssary")
    if Muddy == True:
        print("Wear sandal")
    else:
        print("Bring Sneakers")
else:
    print("Go without a rain coat")
# Out:
# Rain coat is Necesssary
# Bring Sneakers

# %%
Taka = 1000

if Taka > 500:
    print("Buy 5 ice cream")
elif Taka > 400:
    print("Buy 4 ice cream")
elif Taka > 300:
    print("Buy 3 ice cream")
else:
    print("Not buy")
# Out:
# Buy 5 ice cream

# %%
Taka = 1000
raining = True

if Taka > 500 and raining == False:
    print("Ghurte jabo")
else:
    print("Ghurte jabo na")
# Out:
# Ghurte jabo na
